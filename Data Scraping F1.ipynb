# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
DATES = ['2019', '2020']
BASE_URL = "https://www.f1fantasytracker.com/"

# %%
def get_driver_url(driver):
    return f"{BASE_URL}{driver}.html"

# %%
def get_soup(url):
    r = requests.get(url) 
    return BeautifulSoup(r.content, 'html5lib')

# %%
def get_drivers():    
    url = f"{BASE_URL}drivers-teams.html"
    soup = get_soup(url)
    driver_rows = soup.findAll('div', attrs = 'driverteamimagewrapper hovereffect')
    drivers = [row.find('a')['href'].replace(".html", "") for row in driver_rows]
    return drivers

drivers = get_drivers()

# %%
def get_stats_table(soup, date):
    return soup.find('div', attrs = {'class': f"{date} box"})

# %%
def stats_table_to_dict(table):
    stats = {}
    rows = table.findAll('div', attrs={'class':'statsTableRow'})
    for row in rows:
        key, value = row.findAll('div')
        stats[key.string] = value.string
    return stats

# %%
def get_driver_stats_tables(drivers, dates):
    stats = []
    for driver in drivers:
        url = get_driver_url(driver)
        soup = get_soup(url)
        for year in dates:
            table = get_stats_table(soup, year)
            if table:
                driver_year_stats = stats_table_to_dict(table)
                driver_year_stats["Season"] = year
                driver_year_stats["Driver"] = driver
                stats.append(driver_year_stats)
    return stats

# %%
tables = get_driver_stats_tables(drivers, DATES)

# %%
stats_df = pd.DataFrame(tables)

# %%
stats_df
# Out:
#    Fantasy Position Average Fantasy Pts DNF Rate Average Overtakes  \
# 0               1st               40.00       0%              -0.1
# 1               1st               40.82       0%             -0.41
# 2               2nd               31.48      10%               0.5
# 3               3rd               25.59       6%             -1.82
# 4               4th               25.80      10%              -0.6
# 5               9th                  14      24%              0.76
# 6               8th               12.33      14%               1.0
# 7               7th               15.88      18%              1.47
# 8               3rd               30.10      10%              0.84
# 9               2nd               26.88      29%              0.41
# 10              7th               13.81      10%              2.63
# 11              5th               18.71      12%             -0.18
# 12             15th                7.24      19%             -0.06
# 13              4th               21.41       6%              0.65
# 14             16th                6.76      19%             -0.44
# 15              6th               17.71       6%              0.71
# 16             14th                8.76      24%              1.71
# 17              5th               24.05      10%              -0.1
# 18              6th                7.47      12%              1.29
# 19             14th                8.05      10%              2.74
# 20             11th               10.53      29%              1.06
# 21              6th               16.81       5%              0.75
# 22             10th               12.82      18%              1.65
# 23              9th               10.86      10%              1.53
# 24             11th               10.53       6%              3.06
# 25             17th                5.33       5%              0.25
# 26             16th                6.06      18%              2.71
# 27             12th                8.81      10%              2.11
# 28             18th                4.53      24%              0.71
# 29             17th                4.71      18%              2.71
#
#    Beat Teammate Rate Top 5 Highest Scorer Fantasy Points Podiums Overtakes  \
# 0                 71%                  90%            841      17         2
# 1                 71%                  88%            699      14        -7
# 2                 29%                  19%            661      15        10
# 3                 29%                  65%            435      11       -31
# 4                 43%                  71%            547      10       -14
# 5                 59%                  35%            238       2        13
# 6                 62%                  14%            262       1        16
# 7                 47%                  35%            270       1        25
# 8                 76%                  81%            630       9        16
# 9                 71%                  65%            457      11         7
# 10                76%                  14%            288       0        49
# 11                59%                  29%            318       2        -3
# 12                52%                  10%            152       0         7
# 13                76%                  53%            364       2        11
# 14                38%                   5%            142       0        -8
# 15                53%                  35%            301       1        12
# 16                24%                  12%            149       1        29
# 17                57%                  67%            510       9        -7
# 18                29%                   6%            127       1        22
# 19                24%                   5%            168       0        51
# 20                41%                  24%            179       2        18
# 21                24%                  48%            353       1        21
# 22                53%                  18%            294       1        28
# 23                81%                   5%            228       0        27
# 24                71%                   0%            177       0        52
# 25                19%                   0%            112       0         3
# 26                29%                   0%            103       0        46
# 27                81%                   0%            185       0        34
# 28                65%                   0%             74       0        12
# 29                35%                   0%             80       0        46
#
#    DNFs Fastest Laps Completed Streaks Season      Driver
# 0     0            6                 8   2019    hamilton
# 1     0            6                 6   2020    hamilton
# 2     1            2                 7   2019      bottas
# 3     1            2                 4   2020      bottas
# 4     2            4                 6   2019     leclerc
# 5     4            0                 1   2020     leclerc
# 6     3            0                 2   2019       sainz
# 7     3            1                 2   2020       sainz
# 8     2            3                 5   2019  verstappen
# 9     5            3                 4   2020  verstappen
# 10    2            0                 1   2019       perez
# 11    2            0                 3   2020       perez
# 12    4            0                 0   2019   ricciardo
# 13    1            2                 4   2020   ricciardo
# 14    4            0                 1   2019      norris
# 15    1            2                 3   2020      norris
# 16    4            0                 0   2020        ocon
# 17    2            2                 5   2019      vettel
# 18    2            0                 0   2020      vettel
# 19    2            0                 0   2019      stroll
# 20    5            0                 2   2020      stroll
# 21    1            2                 2   2019       gasly
# 22    3            0                 0   2020       gasly
# 23    2            0                 0   2019   raikkonen
# 24    1            0                 0   2020   raikkonen
# 25    1            0                 0   2019  giovinazzi
# 26    3            0                 0   2020  giovinazzi
# 27    2            0                 0   2019     russell
# 28    4            0                 0   2020     russell
# 29    3            0                 0   2020      latifi

# %%
stats_df.to_csv("driver_stats.csv")
